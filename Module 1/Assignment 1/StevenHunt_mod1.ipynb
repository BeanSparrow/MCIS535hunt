# %% [markdown]
# # Module 1 Assignment
# #### By: Steven Hunt
#
#
# #### 1. The file to be imported should be passed as a parameter to a function which evaluates what type the importing file is based on its extension and invokes proper function to import the file.
#
# #### 2. There are should have four functions, each of which imports either a CSV, JSON, XML, or Excel file.
# #### 3. There should be function(s) to process data from the imported file. You may show some statistics or output some sample data.
#
# #### 4. You should use RELATIVE file path (not ABSOLUTE/FULL PATH) when importing a file.

# %% [markdown]
# For this module I used the first 100 data points of each of the sample data sets provided in chapters 3 and 4 of the 'Data Wrangling with Python' book.

# %%
# Import Libraries
import os
import xml.etree.ElementTree as ET
import json
import csv
import xlrd

# Identify Data Files in referenced Directory and return list of files with referenced extension
def directory_walker(extension, directory):
    return_list = []
    for root, dirs, files in os.walk(directory):
        for name in files:
            if name.endswith(extension):
                filename = os.path.join(root, name)
                return_list.append(filename)
    
    return return_list

# Function to parse all Json Files in list referenced and add to dictionary with iterative key
def json_parser(data_dict, files):
    counter = 0
    for item in files:
        counter += 1
        with open(item) as f:
            data = json.load(f)
        data_dict['json file ' + str(counter)] = data
    return data_dict

# Function to parse all CSV Files in list reference and add to dictionary with iterative key
def csv_parser(data_dict, files):
    counter = 0
    for item in files:
        counter += 1
        csvfile = open(item,'r')
        data = csv.DictReader(csvfile)

        data_dict['csv file ' + str(counter)] = data
    return data_dict

# Function to parse all XML files in list referenced and add to the dictionary with an iterative key
def xml_parser(data_dict, files):
    counter = 0
    for item in files:
        counter += 1
        tree = ET.parse(item)
        root = tree.getroot()

        data = root.find('Data')

        data_dict['xml file ' + str(counter)] = data
    return data_dict

# Function to parse all Excel files in list referenced and add to the dictionary with an iterative key
def excel_parser(data_dict, files):
    counter = 0
    for item in files:
        counter += 1
        book = xlrd.open_workbook(item)
        sheet = book.sheet_by_name('Table 9 ')

        data = {}
        for i in range(14, 114):
        # Start at 14th row, because that is where the country data begins
            row = sheet.row_values(i)
            country = row[1]
            data[country] = {
                'child_labor': {
                    'total': [row[4], row[5]],
                    'male': [row[6], row[7]],
                    'female': [row[8], row[9]],
                },
                'child_marriage': {
                  'married_by_15': [row[10], row[11]],
                 'married_by_18': [row[12], row[13]],
                }
            }

        data_dict['excel file ' + str(counter)] = data
    
    return data_dict

# %% [markdown]
# The section above is all of the functions that are used in combination to identify the data files in the provided directory and parse the data, outputing into a dictionary where the key is a concatenated string combining the file type and a iteration value for ease of understanding.
#
# There are 5 functions:
#
# directory_walker()
# json_parser()
# csv_parser()
# xml_parser()
# excel_parser()
#
# The directory_walker() function identifies all of the files in a directory and can be used to return a list of all files of a specified file type.
#
# The 4 remaining parser functions are used to parse through the list of files that match the specified filetype.  The Json and CSV functions are designed to handle any file containing data in their individual file formats.  The XML and Excel parsers are unique to the data file that is being used in this code sequence, unfortunately both of those file formats involve a large amount of unique design and the parser would need to be redesigned for each data file depending on the formatting.

# %%
# Function that 
def get_data(directory):

    #Initialize Data Dictionary, Directory, and Filetypes List
    data_dict = {}
    filetypes = ['.csv', '.json', '.xml', '.xls']

    # Create Lists of Each file Type in the Directory
    csv_files = directory_walker(filetypes[0], directory)
    json_files = directory_walker(filetypes[1], directory)
    xml_files = directory_walker(filetypes[2], directory)
    excel_files = directory_walker(filetypes[3], directory)

    #Build Data Dictionary for housing all collected data from each file
    data_dict = json_parser(data_dict, json_files)
    data_dict = csv_parser(data_dict, csv_files)
    data_dict = xml_parser(data_dict, xml_files)
    data_dict = excel_parser(data_dict, excel_files)
    
    return data_dict

# %% [markdown]
# The above function takes a directory argument and then runs all of the files through the parser functions and returns a dictionary with all of the data collected.

# %%
def main():
    directory = 'StevenHunt_Mod1_Data'
    data_dict = get_data(directory)
    
    for key, value in data_dict.items():
        print(key)


main()
# Out:
# json file 1
# csv file 1
# xml file 1
# excel file 1

# %% [markdown]
# The main function executes all of the above code and assigns the data dictionary to the data_dict variable.  From here all of the data can be accessed directly by manipulating the data_dict dictionary. Some examples are below:

# %% [markdown]
# ### CSV Example

# %%
def main_with_csv_file_print():
    directory = 'StevenHunt_Mod1_Data'
    data_dict = get_data(directory)
    for row in data_dict['csv file 1']:
        print(row)

main_with_csv_file_print()
# Out:
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '1920', 'WHO region': 'Americas', 'Country': 'Canada', 'Sex': 'Both sexes', 'Display Value': '82.8', 'Numeric': '82.80972', 'Low': '', 'High': '', 'Comments': 'WHO life table method: Vital registration'}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '54.6', 'Numeric': '54.57449', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '46.9', 'Numeric': '46.93113', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '13.6', 'Numeric': '13.63259', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '59.6', 'Numeric': '59.60036', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '51.5', 'Numeric': '51.50902', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '15.1', 'Numeric': '15.07067', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '61.0', 'Numeric': '61.03658', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '52.8', 'Numeric': '52.78430', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '15.7', 'Numeric': '15.67539', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '63.3', 'Numeric': '63.28709', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '54.7', 'Numeric': '54.73407', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Male', 'Display Value': '15.4', 'Numeric': '15.39356', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '55.4', 'Numeric': '55.41726', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '46.6', 'Numeric': '46.58344', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '14.2', 'Numeric': '14.20647', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '60.3', 'Numeric': '60.29720', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '50.7', 'Numeric': '50.74652', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '15.2', 'Numeric': '15.16855', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '62.3', 'Numeric': '62.34584', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '52.4', 'Numeric': '52.44153', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '15.5', 'Numeric': '15.51821', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '63.2', 'Numeric': '63.15551', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '53.2', 'Numeric': '53.15305', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Female', 'Display Value': '15.1', 'Numeric': '15.05771', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '55.0', 'Numeric': '54.98949', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '46.8', 'Numeric': '46.76397', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '13.9', 'Numeric': '13.92182', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '59.9', 'Numeric': '59.94055', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '51.1', 'Numeric': '51.13087', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '15.1', 'Numeric': '15.12046', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '61.7', 'Numeric': '61.65429', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '52.6', 'Numeric': '52.60495', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '15.6', 'Numeric': '15.58858', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '63.2', 'Numeric': '63.20990', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '53.9', 'Numeric': '53.94961', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Eastern Mediterranean', 'Country': 'Afghanistan', 'Sex': 'Both sexes', 'Display Value': '15.2', 'Numeric': '15.21116', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '46.8', 'Numeric': '46.77004', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '41.2', 'Numeric': '41.18177', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '12.8', 'Numeric': '12.82086', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '55.8', 'Numeric': '55.77834', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '49.3', 'Numeric': '49.27284', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '14.4', 'Numeric': '14.36960', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '59.1', 'Numeric': '59.13242', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '52.2', 'Numeric': '52.18073', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '15.0', 'Numeric': '14.99474', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '60.7', 'Numeric': '60.70384', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '53.6', 'Numeric': '53.55479', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Male', 'Display Value': '15.4', 'Numeric': '15.37612', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '52.1', 'Numeric': '52.12018', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '44.7', 'Numeric': '44.74432', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '16.0', 'Numeric': '16.00562', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '60.5', 'Numeric': '60.52821', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '52.0', 'Numeric': '51.97081', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '17.5', 'Numeric': '17.54322', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '64.5', 'Numeric': '64.49519', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '55.3', 'Numeric': '55.27776', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '18.4', 'Numeric': '18.41525', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '65.5', 'Numeric': '65.51968', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '56.2', 'Numeric': '56.20812', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Female', 'Display Value': '18.6', 'Numeric': '18.55177', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '49.3', 'Numeric': '49.30265', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '42.9', 'Numeric': '42.87378', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '14.4', 'Numeric': '14.41537', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '58.1', 'Numeric': '58.06943', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '50.6', 'Numeric': '50.56540', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '16.0', 'Numeric': '15.97037', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '61.7', 'Numeric': '61.71907', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '53.7', 'Numeric': '53.66165', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '16.7', 'Numeric': '16.70558', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '63.1', 'Numeric': '63.06044', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '54.8', 'Numeric': '54.84173', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Africa', 'Country': 'Angola', 'Sex': 'Both sexes', 'Display Value': '17.0', 'Numeric': '16.98254', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '70.7', 'Numeric': '70.65347', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '63.1', 'Numeric': '63.14932', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '17.1', 'Numeric': '17.10085', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '74.2', 'Numeric': '74.23331', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '66.3', 'Numeric': '66.33651', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '19.9', 'Numeric': '19.94106', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '76.1', 'Numeric': '76.10220', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '68.0', 'Numeric': '67.99379', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '20.1', 'Numeric': '20.13324', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '76.3', 'Numeric': '76.25368', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '68.0', 'Numeric': '67.99864', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Male', 'Display Value': '20.2', 'Numeric': '20.21802', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '76.9', 'Numeric': '76.91914', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '67.7', 'Numeric': '67.68733', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '21.2', 'Numeric': '21.20580', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '78.3', 'Numeric': '78.31106', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '68.9', 'Numeric': '68.85171', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2010', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '22.6', 'Numeric': '22.63415', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '79.7', 'Numeric': '79.68682', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '70.1', 'Numeric': '70.12115', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2015', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '22.2', 'Numeric': '22.15170', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '79.9', 'Numeric': '79.90692', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '70.3', 'Numeric': '70.25225', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2019', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Female', 'Display Value': '21.9', 'Numeric': '21.94139', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Both sexes', 'Display Value': '73.5', 'Numeric': '73.54528', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Healthy life expectancy (HALE) at birth (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Both sexes', 'Display Value': '65.2', 'Numeric': '65.23516', 'Low': '', 'High': '', 'Comments': ''}
# {'Indicator': 'Life expectancy at age 60 (years)', 'PUBLISH STATES': 'Published', 'Year': '2000', 'WHO region': 'Europe', 'Country': 'Albania', 'Sex': 'Both sexes', 'Display Value': '19.0', 'Numeric': '18.99650', 'Low': '', 'High': '', 'Comments': ''}

# %% [markdown]
# ### XML Example

# %%
def main_with_xml_file_print():
    directory = 'StevenHunt_Mod1_Data'
    data_dict = get_data(directory)
    for observation in data_dict['xml file 1']:        
        for child in observation:
            print(child.tag, child.attrib)

main_with_xml_file_print()
# Out:
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'COUNTRY', 'Code': 'AND'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Value {'Numeric': '77.00000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'COUNTRY', 'Code': 'AND'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '80.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'AND'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '28.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'COUNTRY', 'Code': 'AND'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Value {'Numeric': '23.00000'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'REGION', 'Code': 'EMR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'COUNTRY', 'Code': 'ARE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '78.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'ATG'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '72.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'COUNTRY', 'Code': 'ATG'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Value {'Numeric': '17.00000'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'ATG'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '22.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'AUS'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '81.00000'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'COUNTRY', 'Code': 'AUS'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '80.00000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'COUNTRY', 'Code': 'AUS'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '83.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'COUNTRY', 'Code': 'AUT'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Value {'Numeric': '83.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'COUNTRY', 'Code': 'AUT'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Value {'Numeric': '25.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'COUNTRY', 'Code': 'BEL'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Value {'Numeric': '83.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EMR'}
# Dim {'Category': 'COUNTRY', 'Code': 'BHR'}
# Value {'Numeric': '73.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'COUNTRY', 'Code': 'BHR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'REGION', 'Code': 'EMR'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Value {'Numeric': '74.00000'}
# Dim {'Category': 'REGION', 'Code': 'EMR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'BHR'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '17.00000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Dim {'Category': 'COUNTRY', 'Code': 'BHS'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '72.00000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'BHS'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '21.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'COUNTRY', 'Code': 'BRB'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Value {'Numeric': '71.00000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'BRB'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '25.00000'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'BRB'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '23.00000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'BRN'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '20.00000'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'COUNTRY', 'Code': 'BRN'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '22.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'BRN'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '21.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'COUNTRY', 'Code': 'CAN'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '82.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'CAN'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '21.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'COUNTRY', 'Code': 'CAN'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'AMR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Value {'Numeric': '24.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'CHE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '74.00000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'CHE'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '83.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'CHE'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '23.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'COK'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Value {'Numeric': '76.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'COK'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Value {'Numeric': '22.00000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'COUNTRY', 'Code': 'COK'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '18.00000'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'COUNTRY', 'Code': 'CYP'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '79.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'CYP'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '77.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'CYP'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '22.00000'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'CYP'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '26.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'COUNTRY', 'Code': 'CZE'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Value {'Numeric': '75.00000'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'CZE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '75.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'DEU'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '79.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'DEU'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Value {'Numeric': '18.00000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'DEU'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '20.00000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'DNK'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '80.00000'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'COUNTRY', 'Code': 'DNK'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '18.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'COUNTRY', 'Code': 'DNK'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '19.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'DNK'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Value {'Numeric': '21.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'DNK'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '23.00000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'ESP'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '82.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'ESP'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '25.00000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'COUNTRY', 'Code': 'ESP'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '22.00000'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'COUNTRY', 'Code': 'EST'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '75.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'COUNTRY', 'Code': 'EST'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '81.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'EST'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '18.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'COUNTRY', 'Code': 'EST'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '21.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'EST'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '24.00000'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'COUNTRY', 'Code': 'FIN'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '79.00000'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'FIN'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '22.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'COUNTRY', 'Code': 'FRA'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Value {'Numeric': '75.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'COUNTRY', 'Code': 'FRA'}
# Value {'Numeric': '20.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'GBR'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Value {'Numeric': '83.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'COUNTRY', 'Code': 'GBR'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '81.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'GBR'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Value {'Numeric': '18.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'REGION', 'Code': 'AFR'}
# Dim {'Category': 'COUNTRY', 'Code': 'GNQ'}
# Value {'Numeric': '52.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'REGION', 'Code': 'AFR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'GNQ'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Value {'Numeric': '15.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'REGION', 'Code': 'AFR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'GNQ'}
# Value {'Numeric': '17.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'COUNTRY', 'Code': 'GRC'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Value {'Numeric': '78.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'COUNTRY', 'Code': 'GRC'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Value {'Numeric': '83.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'COUNTRY', 'Code': 'HRV'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Value {'Numeric': '78.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'COUNTRY', 'Code': 'HRV'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Value {'Numeric': '16.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'HRV'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Value {'Numeric': '19.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'COUNTRY', 'Code': 'HUN'}
# Value {'Numeric': '68.00000'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'COUNTRY', 'Code': 'HUN'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '72.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'COUNTRY', 'Code': 'HUN'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Value {'Numeric': '15.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'HUN'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '22.00000'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'HUN'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '18.00000'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'COUNTRY', 'Code': 'IRL'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '77.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'IRL'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '19.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'COUNTRY', 'Code': 'IRL'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Value {'Numeric': '20.00000'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'COUNTRY', 'Code': 'ISL'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '84.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'COUNTRY', 'Code': 'ISL'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Value {'Numeric': '24.00000'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'COUNTRY', 'Code': 'ISR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '75.00000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'COUNTRY', 'Code': 'ISR'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '21.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'COUNTRY', 'Code': 'ISR'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '24.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'COUNTRY', 'Code': 'ITA'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '74.00000'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'ITA'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '77.00000'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'COUNTRY', 'Code': 'ITA'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '21.00000'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'ITA'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '25.00000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'JPN'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '29.00000'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'COUNTRY', 'Code': 'JPN'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '23.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'JPN'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '25.00000'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'COUNTRY', 'Code': 'KOR'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '76.00000'}
# Dim {'Category': 'COUNTRY', 'Code': 'KOR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '72.00000'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'COUNTRY', 'Code': 'KOR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'REGION', 'Code': 'WPR'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '23.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'COUNTRY', 'Code': 'KWT'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EMR'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '74.00000'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'REGION', 'Code': 'EMR'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'COUNTRY', 'Code': 'KWT'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '76.00000'}
# Dim {'Category': 'REGION', 'Code': 'EMR'}
# Dim {'Category': 'COUNTRY', 'Code': 'KWT'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'SEX', 'Code': 'FMLE'}
# Dim {'Category': 'YEAR', 'Code': '1990'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '18.00000'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'COUNTRY', 'Code': 'LUX'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '75.00000'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000001'}
# Dim {'Category': 'COUNTRY', 'Code': 'LUX'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'SEX', 'Code': 'BTSX'}
# Dim {'Category': 'YEAR', 'Code': '2012'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Value {'Numeric': '82.00000'}
# Dim {'Category': 'PUBLISHSTATE', 'Code': 'PUBLISHED'}
# Dim {'Category': 'REGION', 'Code': 'EUR'}
# Dim {'Category': 'GHO', 'Code': 'WHOSIS_000015'}
# Dim {'Category': 'SEX', 'Code': 'MLE'}
# Dim {'Category': 'WORLDBANKINCOMEGROUP', 'Code': 'WB_HI'}
# Dim {'Category': 'YEAR', 'Code': '2000'}
# Dim {'Category': 'COUNTRY', 'Code': 'LUX'}
# Value {'Numeric': '20.00000'}

# %% [markdown]
# Using the Key values it is possible to isolate and access each data set from the dictionary.
