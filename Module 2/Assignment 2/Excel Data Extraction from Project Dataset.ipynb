# %% [markdown]
# # Pandas Excel Extraction

# %%
import pandas as pd
import numpy as np

workbook = pd.read_excel('data\Total Education and Mean Income By year.xlsx')
workbook.head()
# Out:
#    Year  Total_mean  Total_Population Total_Std_Err  No_HS_Mean  \
# 0  2019     58544.0          167215.0           329     29278.0
# 1  2018     55619.0          165179.0           296     27037.0
# 2  2017     53536.0          163871.0           218     26832.0
# 3  2016     51893.0          162218.0           217     27800.0
# 4  2015     49994.0          161074.0           209     25315.0
#
#    No_HS_Population No_HS_Std_Err  HS_Mean  HS_Population HS_Std_Err  \
# 0           11413.0           552  39371.0        42598.0        329
# 1           12058.0           481  38936.0        42882.0        376
# 2           12240.0           383  38145.0        42816.0        320
# 3           12281.0           559  36702.0        42897.0        296
# 4           13159.0           422  35615.0        42404.0        271
#
#    Some_Clg_AD_Mean  Some_clg_AD_Population Some_Clg_AD_Std_Err  BD_Mean  \
# 0           45091.0                 46885.0                 411  73163.0
# ...
